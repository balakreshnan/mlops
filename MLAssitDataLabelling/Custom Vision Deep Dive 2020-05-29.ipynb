# %% [markdown]
# # Custom Vision Deep Dive
# ## Contents
# 1. Deploy Resources
# - Prepare Data
#   - Convert VIA's COCO annotation json files to PASCAL VOC xml format
#   - Resize images to less than 6MB
# - Create a Custom Vision service project
#   - Apply resizing factor and normalize tag coordinates
#   - Upload images and tag to project
#   - Train the project
#   - Evaluate model
#
# ### Useful Resources
# - Python SDK Docs: https://docs.microsoft.com/en-us/python/api/azure-cognitiveservices-vision-customvision/?view=azure-python
# - Python Custom Vision Client Lib: https://pypi.org/project/azure-cognitiveservices-vision-customvision/
# - Azure SDK for Python: https://github.com/Azure/azure-sdk-for-python/

# %% [markdown]
# ## Deploy Resources
# In your Azure Portal,tart by deploying
# 1. Custom Vision https://portal.azure.com/#create/Microsoft.CognitiveServicesCustomVision
#   - Deploy both Training and Prediciton Resources in the same location (e.g. East US) at same pricing tier (S0)
#
# - Machine Learning https://portal.azure.com/#create/Microsoft.MachineLearningServices
#   - Deploy in same location with "Enterprise" as the Workspace Edition

# %% [markdown]
# ## Prepare data
# ### Convert VIA's COCO annotation json files to PASCAL VOC xml format

# %%
import argparse, json
import cytoolz
from lxml import etree, objectify
import os, re
import urllib.request, pdb
from pathlib import Path
import glob, os

USE_SUBFOLDERS = False
USE_ORIG_CODE = False
DOWNLOAD_IMAGES = True

# %%
# Helper function: Takes a COCO json and returns first level xml file structure

def instance2xml_base(anno):
    E = objectify.ElementMaker(annotate=False)
    anno_tree = E.annotation(
        
        E.folder('VOC2014_instance/{}'.format(anno['category_id'])),
        E.filename(anno['file_name']),
        E.source(
            E.database('MS COCO 2014'),
            E.annotation('MS COCO 2014'),
            E.image('Flickr'),
            E.url(anno['coco_url'])
        ),
        E.size(
            E.width(anno['width']),
            E.height(anno['height']),
            E.depth(3)
        ),
        E.segmented(0),
    )
    return anno_tree

# %%
# Helper function: Takes bounding box and returns xml element with structured coordinate info

def instance2xml_bbox(anno, bbox_type='xyxy'):
    """bbox_type: xyxy (xmin, ymin, xmax, ymax); xywh (xmin, ymin, width, height)"""
    assert bbox_type in ['xyxy', 'xywh']
    if bbox_type == 'xyxy':
        xmin, ymin, w, h = anno['bbox']
        xmax = xmin+w
        ymax = ymin+h
    else:
        xmin, ymin, xmax, ymax = anno['bbox']
    E = objectify.ElementMaker(annotate=False)
    anno_tree = E.object(
        E.name(anno['category_id']),
        E.bndbox(
            E.xmin(xmin),
            E.ymin(ymin),
            E.xmax(xmax),
            E.ymax(ymax)
        ),
        E.difficult(anno['iscrowd'])
    )
    return anno_tree

# %%
# Takes COCO json and returns PASCAL VOC

def parse_instance(content, outdir):
    categories = {d['id']: d['name'] for d in content['categories']}
    # merge images and annotations: id in images vs image_id in annotations
    
    # Converts "image_id" in json from str to int
    if not USE_ORIG_CODE: 
        for i in range(len(content['annotations'])):
            content['annotations'][i]['image_id'] = int(content['annotations'][i]['image_id'])

    # PATRICK - need to download images and update the filename field
    if DOWNLOAD_IMAGES:
        im_dir = os.path.join(outdir, "images")
        if not os.path.exists(im_dir):
            os.makedirs(im_dir)
    anno_dir = os.path.join(outdir, "annotations")
    if not os.path.exists(anno_dir):
        os.makedirs(anno_dir)

    # PATRICK - need to update 'filename' field so that looks like a local file and not a url
    if DOWNLOAD_IMAGES:
        if not USE_ORIG_CODE: 
            for obj in content['images']:
                im_local_filename = os.path.splitext(os.path.basename(obj['file_name']))[0] + ".jpg"
                obj['file_name'] = im_local_filename

                # download image
                dst_path = os.path.join(im_dir, im_local_filename)
                urllib.request.urlretrieve(obj['coco_url'], dst_path)


    merged_info_list = list(map(cytoolz.merge, cytoolz.join('id', content['images'], 'image_id', content['annotations'])))

    # convert category id to name
    for instance in merged_info_list:
        try:
            instance['category_id'] = categories[instance['category_id']]
        except KeyError:
            instance['category_id'] = -1
            print(instance)
    # group by filename to pool all bbox in same file


    img_filenames = {}
    for name, groups in cytoolz.groupby('file_name', merged_info_list).items():
        anno_tree = instance2xml_base(groups[0])
        # if one file have multiple different objects, save it in each category sub-directory
        filenames = []
        for group in groups:
            filename = os.path.splitext(name)[0] + ".xml"

            # PATRICK - save all annotations in single folder, rather than separate folders for each object 
            if USE_SUBFOLDERS:
                filenames.append(os.path.join(outdir, re.sub(" ", "_", group['category_id']), filename)) 
            else:
                filenames.append(os.path.join(outdir, "annotations", filename))

            anno_tree.append(instance2xml_bbox(group, bbox_type='xyxy'))

        for filename in filenames:
            print(filename)
            etree.ElementTree(anno_tree).write(filename, pretty_print=True)
        print("Formating instance xml file {} done!".format(name))

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--anno_file", help="annotation file for object instance/keypoint")
parser.add_argument("--type", type=str, help="object instance or keypoint", choices=['instance', 'keypoint'])
parser.add_argument("--output_dir", help="output directory for voc annotation xml file")

args = parser.parse_args(['--anno_file', './test.json', '--type', 'instance', '--output_dir', './output'])

def coco2voc(args):
    if not os.path.exists(args.output_dir):
        os.makedirs(args.output_dir)
    content = json.load(open(args.anno_file, 'r'))
    if args.type == 'instance':
        parse_instance(content, args.output_dir)

# %%
filepath = "VIA - AeroLabs 2019_12.12 Project 02 SCOTT 2020_01.29 EDDIE 2020_01.23 export_coco.json"
fileStem = Path(filepath).stem # removes file extension
output_dir = './'
args = parser.parse_args(['--anno_file', filepath, '--type', 'instance', '--output_dir', output_dir])

coco2voc(args)
# Out:
# {'id': 111, 'width': -1, 'height': -1, 'file_name': '_PRCuKUcqrNJZ1cnty50AYA==..jpg', 'license': 1, 'flickr_url': 'https://customersiteimages.blob.core.windows.net/tenant-7/_PRCuKUcqrNJZ1cnty50AYA==..JPG', 'coco_url': 'https://customersiteimages.blob.core.windows.net/tenant-7/_PRCuKUcqrNJZ1cnty50AYA==..JPG', 'date_captured': '', 'image_id': 10, 'segmentation': [3233, 522, 2920, 518, 2882, 3413, 3074, 3400], 'area': 1016145, 'bbox': [2882, 518, 351, 2895], 'iscrowd': 0, 'category_id': -1}
# {'id': 181, 'width': -1, 'height': -1, 'file_name': '_w05T7MCiPFNBTqdZ7J4Ebw==..jpg', 'license': 1, 'flickr_url': 'https://customersiteimages.blob.core.windows.net/tenant-7/_w05T7MCiPFNBTqdZ7J4Ebw==..JPG', 'coco_url': 'https://customersiteimages.blob.core.windows.net/tenant-7/_w05T7MCiPFNBTqdZ7J4Ebw==..JPG', 'date_captured': '', 'image_id': 19, 'segmentation': [2828, 819, 3333, 835, 2907, 3609, 2636, 3580], 'area': 1944630, 'bbox': [2636, 819, 697, 2790], 'iscrowd': 0, 'category_id': -1}
# {'id': 257, 'width': -1, 'height': -1, 'file_name': '43795-39759_hhAvT6bZSUqiX1Uvnm_htw==..jpg', 'license': 1, 'flickr_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/43795-39759_hhAvT6bZSUqiX1Uvnm_htw==..JPG', 'coco_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/43795-39759_hhAvT6bZSUqiX1Uvnm_htw==..JPG', 'date_captured': '', 'image_id': 29, 'segmentation': [1744, 1076, 3533, 2293, 3391, 2435, 1550, 1288, 1696, 1063], 'area': 2720676, 'bbox': [1550, 1063, 1983, 1372], 'iscrowd': 0, 'category_id': -1}
# {'id': 354, 'width': -1, 'height': -1, 'file_name': '43489-39586_sDQABWrQ8qV_rm3I+dXXYA==..jpg', 'license': 1, 'flickr_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/43489-39586_sDQABWrQ8qV_rm3I+dXXYA==..JPG', 'coco_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/43489-39586_sDQABWrQ8qV_rm3I+dXXYA==..JPG', 'date_captured': '', 'image_id': 47, 'segmentation': [1337, 1628, 4393, 1698, 4367, 1543, 961, 1484, 880, 1477, 851, 1624], 'area': 782782, 'bbox': [851, 1477, 3542, 221], 'iscrowd': 0, 'category_id': -1}
# {'id': 422, 'width': -1, 'height': -1, 'file_name': '48264-45436_HXR_D9ZR6d20tVst8AxAJA==..jpg', 'license': 1, 'flickr_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48264-45436_HXR_D9ZR6d20tVst8AxAJA==..JPG', 'coco_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48264-45436_HXR_D9ZR6d20tVst8AxAJA==..JPG', 'date_captured': '', 'image_id': 56, 'segmentation': [1811, 2083, 1913, 2185, 3981, 571, 3874, 504], 'area': 3647770, 'bbox': [1811, 504, 2170, 1681], 'iscrowd': 0, 'category_id': -1}
# {'id': 423, 'width': -1, 'height': -1, 'file_name': '48264-45436_HXR_D9ZR6d20tVst8AxAJA==..jpg', 'license': 1, 'flickr_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48264-45436_HXR_D9ZR6d20tVst8AxAJA==..JPG', 'coco_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48264-45436_HXR_D9ZR6d20tVst8AxAJA==..JPG', 'date_captured': '', 'image_id': 56, 'segmentation': [2723, 1014, 2997, 921, 2984, 2214, 2807, 2218], 'area': 355378, 'bbox': [2723, 921, 274, 1297], 'iscrowd': 0, 'category_id': -1}
# {'id': 424, 'width': -1, 'height': -1, 'file_name': '48264-45436_HXR_D9ZR6d20tVst8AxAJA==..jpg', 'license': 1, 'flickr_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48264-45436_HXR_D9ZR6d20tVst8AxAJA==..JPG', 'coco_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48264-45436_HXR_D9ZR6d20tVst8AxAJA==..JPG', 'date_captured': '', 'image_id': 56, 'segmentation': [2050, 2205, 2154, 2324, 3830, 974, 3714, 899], 'area': 2536500, 'bbox': [2050, 899, 1780, 1425], 'iscrowd': 0, 'category_id': -1}
# {'id': 431, 'width': -1, 'height': -1, 'file_name': '48403-44757_RgXpxUsjClQQTX0jYGcvzg==..jpg', 'license': 1, 'flickr_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48403-44757_RgXpxUsjClQQTX0jYGcvzg==..JPG', 'coco_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48403-44757_RgXpxUsjClQQTX0jYGcvzg==..JPG', 'date_captured': '', 'image_id': 57, 'segmentation': [2145, 1468, 3107, 2451, 3242, 2387, 3242, 2216, 2387, 1268, 2145, 1254], 'area': 1313109, 'bbox': [2145, 1254, 1097, 1197], 'iscrowd': 0, 'category_id': -1}
# {'id': 443, 'width': -1, 'height': -1, 'file_name': '48517-45586_BYZvoL_B_X9H8Tjet5_26g==..jpg', 'license': 1, 'flickr_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..JPG', 'coco_url': 'https://aerolabsimagesdev.blob.core.windows.net/tenant-4/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..JPG', 'date_captured': '', 'image_id': 58, 'segmentation': [2976, 361, 2958, 216, 1825, 331, 1858, 420], 'area': 234804, 'bbox': [1825, 216, 1151, 204], 'iscrowd': 0, 'category_id': -1}
# {'id': 547, 'width': -1, 'height': -1, 'file_name': '_dreiPffzzVyBZhSfvZZ7tQ==..jpg', 'license': 1, 'flickr_url': 'https://customersiteimages.blob.core.windows.net/tenant-6/_dreiPffzzVyBZhSfvZZ7tQ==..JPG', 'coco_url': 'https://customersiteimages.blob.core.windows.net/tenant-6/_dreiPffzzVyBZhSfvZZ7tQ==..JPG', 'date_captured': '', 'image_id': 71, 'segmentation': [2908, 3112, 3014, 3092, 2876, 2252, 2813, 2270, 2828, 2631], 'area': 172860, 'bbox': [2813, 2252, 201, 860], 'iscrowd': 0, 'category_id': -1}
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# ./annotations/48447-44748_OkxAwY73K6UgXm7xbRlG2A==..xml
# Formating instance xml file 48447-44748_OkxAwY73K6UgXm7xbRlG2A==..jpg done!
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# ./annotations/_AJleV_HyaWUsbaWfucTubQ==..xml
# Formating instance xml file _AJleV_HyaWUsbaWfucTubQ==..jpg done!
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# ./annotations/_zL7kG1WfdnGt484mnnkNMg==..xml
# Formating instance xml file _zL7kG1WfdnGt484mnnkNMg==..jpg done!
# ./annotations/_86phbF2IUGlDgnLjWM3cfw==..xml
# ./annotations/_86phbF2IUGlDgnLjWM3cfw==..xml
# ./annotations/_86phbF2IUGlDgnLjWM3cfw==..xml
# ./annotations/_86phbF2IUGlDgnLjWM3cfw==..xml
# ./annotations/_86phbF2IUGlDgnLjWM3cfw==..xml
# ./annotations/_86phbF2IUGlDgnLjWM3cfw==..xml
# ./annotations/_86phbF2IUGlDgnLjWM3cfw==..xml
# Formating instance xml file _86phbF2IUGlDgnLjWM3cfw==..jpg done!
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# ./annotations/_jTWvx9thlZkzRqoqxMWwBw==..xml
# Formating instance xml file _jTWvx9thlZkzRqoqxMWwBw==..jpg done!
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# ./annotations/_ToOjW7j5E9ZYbtIfdfFVww==..xml
# Formating instance xml file _ToOjW7j5E9ZYbtIfdfFVww==..jpg done!
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# ./annotations/_yCEU4OXNxeK8dFvNZKynFw==..xml
# Formating instance xml file _yCEU4OXNxeK8dFvNZKynFw==..jpg done!
# ./annotations/_gYpMA7AgxusxMRPMGClh6A==..xml
# ./annotations/_gYpMA7AgxusxMRPMGClh6A==..xml
# ./annotations/_gYpMA7AgxusxMRPMGClh6A==..xml
# ./annotations/_gYpMA7AgxusxMRPMGClh6A==..xml
# ./annotations/_gYpMA7AgxusxMRPMGClh6A==..xml
# ./annotations/_gYpMA7AgxusxMRPMGClh6A==..xml
# Formating instance xml file _gYpMA7AgxusxMRPMGClh6A==..jpg done!
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# ./annotations/_p+bWcTEBcnb5FMQkLT819w==..xml
# Formating instance xml file _p+bWcTEBcnb5FMQkLT819w==..jpg done!
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# ./annotations/_2UJH1jckj0p9BkDADBDXUA==..xml
# Formating instance xml file _2UJH1jckj0p9BkDADBDXUA==..jpg done!
# ./annotations/_PRCuKUcqrNJZ1cnty50AYA==..xml
# ./annotations/_PRCuKUcqrNJZ1cnty50AYA==..xml
# ./annotations/_PRCuKUcqrNJZ1cnty50AYA==..xml
# ./annotations/_PRCuKUcqrNJZ1cnty50AYA==..xml
# ./annotations/_PRCuKUcqrNJZ1cnty50AYA==..xml
# ./annotations/_PRCuKUcqrNJZ1cnty50AYA==..xml
# ./annotations/_PRCuKUcqrNJZ1cnty50AYA==..xml
# ./annotations/_PRCuKUcqrNJZ1cnty50AYA==..xml
# ./annotations/_PRCuKUcqrNJZ1cnty50AYA==..xml
# Formating instance xml file _PRCuKUcqrNJZ1cnty50AYA==..jpg done!
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# ./annotations/48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..xml
# Formating instance xml file 48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..jpg done!
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# ./annotations/_EFoDyyka_z4FPQMeUI4Wjw==..xml
# Formating instance xml file _EFoDyyka_z4FPQMeUI4Wjw==..jpg done!
# ./annotations/48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..xml
# ./annotations/48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..xml
# ./annotations/48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..xml
# ./annotations/48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..xml
# ./annotations/48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..xml
# ./annotations/48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..xml
# ./annotations/48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..xml
# ./annotations/48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..xml
# ./annotations/48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..xml
# Formating instance xml file 48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..jpg done!
# ./annotations/_K7R07veKO6vPht0NpalMCg==..xml
# ./annotations/_K7R07veKO6vPht0NpalMCg==..xml
# ./annotations/_K7R07veKO6vPht0NpalMCg==..xml
# ./annotations/_K7R07veKO6vPht0NpalMCg==..xml
# Formating instance xml file _K7R07veKO6vPht0NpalMCg==..jpg done!
# ./annotations/48027-45005_XJ+yidGceiNZ1B0PfaRjCg==..xml
# ./annotations/48027-45005_XJ+yidGceiNZ1B0PfaRjCg==..xml
# ./annotations/48027-45005_XJ+yidGceiNZ1B0PfaRjCg==..xml
# ./annotations/48027-45005_XJ+yidGceiNZ1B0PfaRjCg==..xml
# ./annotations/48027-45005_XJ+yidGceiNZ1B0PfaRjCg==..xml
# ./annotations/48027-45005_XJ+yidGceiNZ1B0PfaRjCg==..xml
# Formating instance xml file 48027-45005_XJ+yidGceiNZ1B0PfaRjCg==..jpg done!
# ./annotations/48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..xml
# ./annotations/48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..xml
# ./annotations/48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..xml
# ./annotations/48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..xml
# ./annotations/48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..xml
# ./annotations/48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..xml
# ./annotations/48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..xml
# ./annotations/48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..xml
# ./annotations/48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..xml
# Formating instance xml file 48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..jpg done!
# ./annotations/_3pi3PBtkjqn0h7mwdwvnaw==..xml
# ./annotations/_3pi3PBtkjqn0h7mwdwvnaw==..xml
# ./annotations/_3pi3PBtkjqn0h7mwdwvnaw==..xml
# ./annotations/_3pi3PBtkjqn0h7mwdwvnaw==..xml
# ./annotations/_3pi3PBtkjqn0h7mwdwvnaw==..xml
# Formating instance xml file _3pi3PBtkjqn0h7mwdwvnaw==..jpg done!
# ./annotations/_K9rvmfFvv680MbhLrX9H+w==..xml
# ./annotations/_K9rvmfFvv680MbhLrX9H+w==..xml
# ./annotations/_K9rvmfFvv680MbhLrX9H+w==..xml
# ./annotations/_K9rvmfFvv680MbhLrX9H+w==..xml
# ./annotations/_K9rvmfFvv680MbhLrX9H+w==..xml
# ./annotations/_K9rvmfFvv680MbhLrX9H+w==..xml
# ./annotations/_K9rvmfFvv680MbhLrX9H+w==..xml
# ./annotations/_K9rvmfFvv680MbhLrX9H+w==..xml
# ./annotations/_K9rvmfFvv680MbhLrX9H+w==..xml
# Formating instance xml file _K9rvmfFvv680MbhLrX9H+w==..jpg done!
# ./annotations/_w05T7MCiPFNBTqdZ7J4Ebw==..xml
# ./annotations/_w05T7MCiPFNBTqdZ7J4Ebw==..xml
# ./annotations/_w05T7MCiPFNBTqdZ7J4Ebw==..xml
# ./annotations/_w05T7MCiPFNBTqdZ7J4Ebw==..xml
# Formating instance xml file _w05T7MCiPFNBTqdZ7J4Ebw==..jpg done!
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# ./annotations/47956-45186_g515Tcx6AHWlXCskf8gCNA==..xml
# Formating instance xml file 47956-45186_g515Tcx6AHWlXCskf8gCNA==..jpg done!
# ./annotations/48449-44716_T5qmwRUNIx_cvvSwjSBO_g==..xml
# ./annotations/48449-44716_T5qmwRUNIx_cvvSwjSBO_g==..xml
# ./annotations/48449-44716_T5qmwRUNIx_cvvSwjSBO_g==..xml
# ./annotations/48449-44716_T5qmwRUNIx_cvvSwjSBO_g==..xml
# ./annotations/48449-44716_T5qmwRUNIx_cvvSwjSBO_g==..xml
# ./annotations/48449-44716_T5qmwRUNIx_cvvSwjSBO_g==..xml
# ./annotations/48449-44716_T5qmwRUNIx_cvvSwjSBO_g==..xml
# Formating instance xml file 48449-44716_T5qmwRUNIx_cvvSwjSBO_g==..jpg done!
# ./annotations/48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..xml
# ./annotations/48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..xml
# ./annotations/48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..xml
# ./annotations/48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..xml
# ./annotations/48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..xml
# ./annotations/48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..xml
# ./annotations/48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..xml
# ./annotations/48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..xml
# Formating instance xml file 48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..jpg done!
# ./annotations/_32aBcoIvqfcK2hhpqqePXw==..xml
# ./annotations/_32aBcoIvqfcK2hhpqqePXw==..xml
# ./annotations/_32aBcoIvqfcK2hhpqqePXw==..xml
# ./annotations/_32aBcoIvqfcK2hhpqqePXw==..xml
# ./annotations/_32aBcoIvqfcK2hhpqqePXw==..xml
# Formating instance xml file _32aBcoIvqfcK2hhpqqePXw==..jpg done!
# ./annotations/_f7gREAd+dsWPd5M6+N3ORA==..xml
# ./annotations/_f7gREAd+dsWPd5M6+N3ORA==..xml
# ./annotations/_f7gREAd+dsWPd5M6+N3ORA==..xml
# Formating instance xml file _f7gREAd+dsWPd5M6+N3ORA==..jpg done!
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# ./annotations/_M4Zpolym1GroX+M6aYx6fg==..xml
# Formating instance xml file _M4Zpolym1GroX+M6aYx6fg==..jpg done!
# ./annotations/_qdSoSQz44kg5rxUCgY86jw==..xml
# ./annotations/_qdSoSQz44kg5rxUCgY86jw==..xml
# ./annotations/_qdSoSQz44kg5rxUCgY86jw==..xml
# ./annotations/48254-44861_YCfn84E91kzEu6xdbISP3A==..xml
# Formating instance xml file 48254-44861_YCfn84E91kzEu6xdbISP3A==..jpg done!
# ./annotations/48540-44641_jJgWMZLcj3Nr8CDj+Tf68w==..xml
# ./annotations/48540-44641_jJgWMZLcj3Nr8CDj+Tf68w==..xml
# ./annotations/48540-44641_jJgWMZLcj3Nr8CDj+Tf68w==..xml
# ./annotations/48540-44641_jJgWMZLcj3Nr8CDj+Tf68w==..xml
# ./annotations/48540-44641_jJgWMZLcj3Nr8CDj+Tf68w==..xml
# Formating instance xml file 48540-44641_jJgWMZLcj3Nr8CDj+Tf68w==..jpg done!
# ./annotations/_1im_mPd94ZKhS9XpmvE4rQ==..xml
# ./annotations/_1im_mPd94ZKhS9XpmvE4rQ==..xml
# ./annotations/_1im_mPd94ZKhS9XpmvE4rQ==..xml
# ./annotations/_1im_mPd94ZKhS9XpmvE4rQ==..xml
# ./annotations/_1im_mPd94ZKhS9XpmvE4rQ==..xml
# Formating instance xml file _1im_mPd94ZKhS9XpmvE4rQ==..jpg done!
# ./annotations/_9ZkiFaHbEdlFNn_aeWJuMA==..xml
# ./annotations/_9ZkiFaHbEdlFNn_aeWJuMA==..xml
# ./annotations/_9ZkiFaHbEdlFNn_aeWJuMA==..xml
# ./annotations/_9ZkiFaHbEdlFNn_aeWJuMA==..xml
# ./annotations/_9ZkiFaHbEdlFNn_aeWJuMA==..xml
# ./annotations/_9ZkiFaHbEdlFNn_aeWJuMA==..xml
# Formating instance xml file _9ZkiFaHbEdlFNn_aeWJuMA==..jpg done!
# ./annotations/_ctqz3frTpwsY3P7TcSy4JQ==..xml
# ./annotations/_ctqz3frTpwsY3P7TcSy4JQ==..xml
# ./annotations/_ctqz3frTpwsY3P7TcSy4JQ==..xml
# ./annotations/_ctqz3frTpwsY3P7TcSy4JQ==..xml
# ./annotations/_ctqz3frTpwsY3P7TcSy4JQ==..xml
# ./annotations/_ctqz3frTpwsY3P7TcSy4JQ==..xml
# ./annotations/_ctqz3frTpwsY3P7TcSy4JQ==..xml
# Formating instance xml file _ctqz3frTpwsY3P7TcSy4JQ==..jpg done!
# ./annotations/_eVelLFLltORKvrOcBLB7Gg==..xml
# ./annotations/_eVelLFLltORKvrOcBLB7Gg==..xml
# ./annotations/_eVelLFLltORKvrOcBLB7Gg==..xml
# ./annotations/_eVelLFLltORKvrOcBLB7Gg==..xml
# ./annotations/_eVelLFLltORKvrOcBLB7Gg==..xml
# ./annotations/_eVelLFLltORKvrOcBLB7Gg==..xml
# Formating instance xml file _eVelLFLltORKvrOcBLB7Gg==..jpg done!
# ./annotations/_h1cuUSuc7T9YMYqgMuPJew==..xml
# ./annotations/_h1cuUSuc7T9YMYqgMuPJew==..xml
# ./annotations/_h1cuUSuc7T9YMYqgMuPJew==..xml
# ./annotations/_h1cuUSuc7T9YMYqgMuPJew==..xml
# ./annotations/_h1cuUSuc7T9YMYqgMuPJew==..xml
# Formating instance xml file _h1cuUSuc7T9YMYqgMuPJew==..jpg done!
# ./annotations/_Jvxp9UDrQx7QYTR+d1uvKg==..xml
# ./annotations/_Jvxp9UDrQx7QYTR+d1uvKg==..xml
# ./annotations/_Jvxp9UDrQx7QYTR+d1uvKg==..xml
# ./annotations/_Jvxp9UDrQx7QYTR+d1uvKg==..xml
# ./annotations/_Jvxp9UDrQx7QYTR+d1uvKg==..xml
# ./annotations/_Jvxp9UDrQx7QYTR+d1uvKg==..xml
# Formating instance xml file _Jvxp9UDrQx7QYTR+d1uvKg==..jpg done!
# ./annotations/_LhgPrCp3OsUN36x2gvaFgA==..xml
# ./annotations/_LhgPrCp3OsUN36x2gvaFgA==..xml
# ./annotations/_LhgPrCp3OsUN36x2gvaFgA==..xml
# ./annotations/_LhgPrCp3OsUN36x2gvaFgA==..xml
# ./annotations/_LhgPrCp3OsUN36x2gvaFgA==..xml
# Formating instance xml file _LhgPrCp3OsUN36x2gvaFgA==..jpg done!
# ./annotations/_Ofv4uL7f3LqG4hhLUfpoqQ==..xml
# ./annotations/_Ofv4uL7f3LqG4hhLUfpoqQ==..xml
# ./annotations/_Ofv4uL7f3LqG4hhLUfpoqQ==..xml
# ./annotations/_Ofv4uL7f3LqG4hhLUfpoqQ==..xml
# Formating instance xml file _Ofv4uL7f3LqG4hhLUfpoqQ==..jpg done!
# ./annotations/_t3_yc0oeHJDH3fIdIiSXHA==..xml
# ./annotations/_t3_yc0oeHJDH3fIdIiSXHA==..xml
# ./annotations/_t3_yc0oeHJDH3fIdIiSXHA==..xml
# Formating instance xml file _t3_yc0oeHJDH3fIdIiSXHA==..jpg done!
# ./annotations/_vcDZ8PNy0+PXDTH0BOnHeQ==..xml
# ./annotations/_vcDZ8PNy0+PXDTH0BOnHeQ==..xml
# ./annotations/_vcDZ8PNy0+PXDTH0BOnHeQ==..xml
# ./annotations/_vcDZ8PNy0+PXDTH0BOnHeQ==..xml
# ./annotations/_vcDZ8PNy0+PXDTH0BOnHeQ==..xml
# ./annotations/_vcDZ8PNy0+PXDTH0BOnHeQ==..xml
# Formating instance xml file _vcDZ8PNy0+PXDTH0BOnHeQ==..jpg done!
# ./annotations/_yMVtyS4P2CCdH7DZZKEG1w==..xml
# ./annotations/_yMVtyS4P2CCdH7DZZKEG1w==..xml
# ./annotations/_yMVtyS4P2CCdH7DZZKEG1w==..xml
# ./annotations/_yMVtyS4P2CCdH7DZZKEG1w==..xml
# Formating instance xml file _yMVtyS4P2CCdH7DZZKEG1w==..jpg done!
# ./annotations/_3ZXATdePcjFnP2KEiyWfUw==..xml
# ./annotations/_3ZXATdePcjFnP2KEiyWfUw==..xml
# ./annotations/_3ZXATdePcjFnP2KEiyWfUw==..xml
# Formating instance xml file _3ZXATdePcjFnP2KEiyWfUw==..jpg done!
# ./annotations/_esA_fj8QGcW8pogpZlk7Ww==..xml
# ./annotations/_esA_fj8QGcW8pogpZlk7Ww==..xml
# ./annotations/_esA_fj8QGcW8pogpZlk7Ww==..xml
# ./annotations/_esA_fj8QGcW8pogpZlk7Ww==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# ./annotations/48517-45586_BYZvoL_B_X9H8Tjet5_26g==..xml
# Formating instance xml file 48517-45586_BYZvoL_B_X9H8Tjet5_26g==..jpg done!
# ./annotations/48602-45701_iZS5mWpIePH_kucVcIATYw==..xml
# ./annotations/48602-45701_iZS5mWpIePH_kucVcIATYw==..xml
# ./annotations/48602-45701_iZS5mWpIePH_kucVcIATYw==..xml
# ./annotations/48602-45701_iZS5mWpIePH_kucVcIATYw==..xml
# ./annotations/48602-45701_iZS5mWpIePH_kucVcIATYw==..xml
# ./annotations/48602-45701_iZS5mWpIePH_kucVcIATYw==..xml
# Formating instance xml file 48602-45701_iZS5mWpIePH_kucVcIATYw==..jpg done!
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# ./annotations/48616-45641_ViGQs96JhXKOkKP4wWac8w==..xml
# Formating instance xml file 48616-45641_ViGQs96JhXKOkKP4wWac8w==..jpg done!
# ./annotations/__XSa9hJq_GZEu_o21p_oIg==..xml
# ./annotations/__XSa9hJq_GZEu_o21p_oIg==..xml
# ./annotations/__XSa9hJq_GZEu_o21p_oIg==..xml
# ./annotations/__XSa9hJq_GZEu_o21p_oIg==..xml
# ./annotations/__XSa9hJq_GZEu_o21p_oIg==..xml
# Formating instance xml file __XSa9hJq_GZEu_o21p_oIg==..jpg done!
# ./annotations/_1XVBHnAH6_wvpg2Q5XIJTA==..xml
# ./annotations/_1XVBHnAH6_wvpg2Q5XIJTA==..xml
# ./annotations/_1XVBHnAH6_wvpg2Q5XIJTA==..xml
# ./annotations/_1XVBHnAH6_wvpg2Q5XIJTA==..xml
# ./annotations/_1XVBHnAH6_wvpg2Q5XIJTA==..xml
# ./annotations/_1XVBHnAH6_wvpg2Q5XIJTA==..xml
# ./annotations/_1XVBHnAH6_wvpg2Q5XIJTA==..xml
# ./annotations/_1XVBHnAH6_wvpg2Q5XIJTA==..xml
# Formating instance xml file _1XVBHnAH6_wvpg2Q5XIJTA==..jpg done!
# ./annotations/_3rQ0QSGIhUgbact4LFGAjQ==..xml
# ./annotations/_3rQ0QSGIhUgbact4LFGAjQ==..xml
# ./annotations/_3rQ0QSGIhUgbact4LFGAjQ==..xml
# ./annotations/_3rQ0QSGIhUgbact4LFGAjQ==..xml
# ./annotations/_3rQ0QSGIhUgbact4LFGAjQ==..xml
# Formating instance xml file _3rQ0QSGIhUgbact4LFGAjQ==..jpg done!
# ./annotations/_5_u8RE0T5mgQfkksKBCxfg==..xml
# ./annotations/_5_u8RE0T5mgQfkksKBCxfg==..xml
# ./annotations/_5_u8RE0T5mgQfkksKBCxfg==..xml
# ./annotations/_5_u8RE0T5mgQfkksKBCxfg==..xml
# ./annotations/_5_u8RE0T5mgQfkksKBCxfg==..xml
# Formating instance xml file _5_u8RE0T5mgQfkksKBCxfg==..jpg done!
# ./annotations/_5uom+O3Ej4ccpbDt2BD99A==..xml
# ./annotations/_5uom+O3Ej4ccpbDt2BD99A==..xml
# ./annotations/_5uom+O3Ej4ccpbDt2BD99A==..xml
# ./annotations/_5uom+O3Ej4ccpbDt2BD99A==..xml
# Formating instance xml file _5uom+O3Ej4ccpbDt2BD99A==..jpg done!
# ./annotations/_7xij__ksKfuRgp83TLnzVw==..xml
# ./annotations/_7xij__ksKfuRgp83TLnzVw==..xml
# ./annotations/_7xij__ksKfuRgp83TLnzVw==..xml
# ./annotations/_7xij__ksKfuRgp83TLnzVw==..xml
# ./annotations/_7xij__ksKfuRgp83TLnzVw==..xml
# ./annotations/_7xij__ksKfuRgp83TLnzVw==..xml
# Formating instance xml file _7xij__ksKfuRgp83TLnzVw==..jpg done!
# ./annotations/_9qAjFXdreXit2pv3U27auQ==..xml
# ./annotations/_9qAjFXdreXit2pv3U27auQ==..xml
# ./annotations/_9qAjFXdreXit2pv3U27auQ==..xml
# ./annotations/_9qAjFXdreXit2pv3U27auQ==..xml
# ./annotations/_9qAjFXdreXit2pv3U27auQ==..xml
# ./annotations/_9qAjFXdreXit2pv3U27auQ==..xml
# Formating instance xml file _9qAjFXdreXit2pv3U27auQ==..jpg done!
# ./annotations/_aQqePRY+w72Xg5JHVdNhHQ==..xml
# ./annotations/_aQqePRY+w72Xg5JHVdNhHQ==..xml
# ./annotations/_aQqePRY+w72Xg5JHVdNhHQ==..xml
# ./annotations/_aQqePRY+w72Xg5JHVdNhHQ==..xml
# ./annotations/_aQqePRY+w72Xg5JHVdNhHQ==..xml
# Formating instance xml file _aQqePRY+w72Xg5JHVdNhHQ==..jpg done!
# ./annotations/_C0q7Yp_4Z62b4bR7yd8bRQ==..xml
# ./annotations/_C0q7Yp_4Z62b4bR7yd8bRQ==..xml
# ./annotations/_C0q7Yp_4Z62b4bR7yd8bRQ==..xml
# ./annotations/_C0q7Yp_4Z62b4bR7yd8bRQ==..xml
# ./annotations/_C0q7Yp_4Z62b4bR7yd8bRQ==..xml
# ./annotations/_C0q7Yp_4Z62b4bR7yd8bRQ==..xml
# ./annotations/_C0q7Yp_4Z62b4bR7yd8bRQ==..xml
# Formating instance xml file _C0q7Yp_4Z62b4bR7yd8bRQ==..jpg done!
# ./annotations/_clcxWGwe9cWUafb4Y6FuuA==..xml
# ./annotations/_clcxWGwe9cWUafb4Y6FuuA==..xml
# ./annotations/_clcxWGwe9cWUafb4Y6FuuA==..xml
# ./annotations/_clcxWGwe9cWUafb4Y6FuuA==..xml
# Formating instance xml file _clcxWGwe9cWUafb4Y6FuuA==..jpg done!
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# ./annotations/_dreiPffzzVyBZhSfvZZ7tQ==..xml
# Formating instance xml file _dreiPffzzVyBZhSfvZZ7tQ==..jpg done!
# ./annotations/_F0X_8wWUrGIh1YdOkpVSDQ==..xml
# ./annotations/_F0X_8wWUrGIh1YdOkpVSDQ==..xml
# ./annotations/_F0X_8wWUrGIh1YdOkpVSDQ==..xml
# ./annotations/_F0X_8wWUrGIh1YdOkpVSDQ==..xml
# ./annotations/_F0X_8wWUrGIh1YdOkpVSDQ==..xml
# Formating instance xml file _F0X_8wWUrGIh1YdOkpVSDQ==..jpg done!
# ./annotations/_fVaBf76+ymbjokbBgXTprQ==..xml
# ./annotations/_fVaBf76+ymbjokbBgXTprQ==..xml
# ./annotations/_fVaBf76+ymbjokbBgXTprQ==..xml
# ./annotations/_fVaBf76+ymbjokbBgXTprQ==..xml
# ./annotations/_fVaBf76+ymbjokbBgXTprQ==..xml
# ./annotations/_fVaBf76+ymbjokbBgXTprQ==..xml
# Formating instance xml file _fVaBf76+ymbjokbBgXTprQ==..jpg done!
# ./annotations/_hHaSHJXV7AMZqDkO4taO7A==..xml
# ./annotations/_hHaSHJXV7AMZqDkO4taO7A==..xml
# ./annotations/_hHaSHJXV7AMZqDkO4taO7A==..xml
# ./annotations/_hHaSHJXV7AMZqDkO4taO7A==..xml
# ./annotations/_hHaSHJXV7AMZqDkO4taO7A==..xml
# ./annotations/_hHaSHJXV7AMZqDkO4taO7A==..xml
# Formating instance xml file _hHaSHJXV7AMZqDkO4taO7A==..jpg done!
# ./annotations/_IMO8rK2sKCbj7TNvKRppbg==..xml
# ./annotations/_IMO8rK2sKCbj7TNvKRppbg==..xml
# ./annotations/_IMO8rK2sKCbj7TNvKRppbg==..xml
# ./annotations/_IMO8rK2sKCbj7TNvKRppbg==..xml
# ./annotations/_IMO8rK2sKCbj7TNvKRppbg==..xml
# ./annotations/_IMO8rK2sKCbj7TNvKRppbg==..xml
# ./annotations/_IMO8rK2sKCbj7TNvKRppbg==..xml
# ./annotations/_IMO8rK2sKCbj7TNvKRppbg==..xml
# ./annotations/_IMO8rK2sKCbj7TNvKRppbg==..xml
# Formating instance xml file _IMO8rK2sKCbj7TNvKRppbg==..jpg done!
# ./annotations/_JRs_mHMCPzHSzziYMURidA==..xml
# ./annotations/_JRs_mHMCPzHSzziYMURidA==..xml
# ./annotations/_JRs_mHMCPzHSzziYMURidA==..xml
# ./annotations/_JRs_mHMCPzHSzziYMURidA==..xml
# ./annotations/_JRs_mHMCPzHSzziYMURidA==..xml
# Formating instance xml file _JRs_mHMCPzHSzziYMURidA==..jpg done!
# ./annotations/_kHRSo81BR3+okVcDHEnsSQ==..xml
# ./annotations/_kHRSo81BR3+okVcDHEnsSQ==..xml
# ./annotations/_kHRSo81BR3+okVcDHEnsSQ==..xml
# ./annotations/_kHRSo81BR3+okVcDHEnsSQ==..xml
# ./annotations/_kHRSo81BR3+okVcDHEnsSQ==..xml
# ./annotations/_kHRSo81BR3+okVcDHEnsSQ==..xml
# ./annotations/_kHRSo81BR3+okVcDHEnsSQ==..xml
# ./annotations/_kHRSo81BR3+okVcDHEnsSQ==..xml
# ./annotations/_kHRSo81BR3+okVcDHEnsSQ==..xml
# Formating instance xml file _kHRSo81BR3+okVcDHEnsSQ==..jpg done!
# ./annotations/_ly3VR6sEju+bQhnUKJqZqA==..xml
# ./annotations/_ly3VR6sEju+bQhnUKJqZqA==..xml
# ./annotations/_ly3VR6sEju+bQhnUKJqZqA==..xml
# ./annotations/_ly3VR6sEju+bQhnUKJqZqA==..xml
# Formating instance xml file _ly3VR6sEju+bQhnUKJqZqA==..jpg done!
# ./annotations/_MNLlJAigCS8D285CSP0jsg==..xml
# ./annotations/_MNLlJAigCS8D285CSP0jsg==..xml
# ./annotations/_MNLlJAigCS8D285CSP0jsg==..xml
# ./annotations/_MNLlJAigCS8D285CSP0jsg==..xml
# ./annotations/_MNLlJAigCS8D285CSP0jsg==..xml
# Formating instance xml file _MNLlJAigCS8D285CSP0jsg==..jpg done!
# ./annotations/_NkLYIfVXINkxMM2Ro_MPog==..xml
# ./annotations/_NkLYIfVXINkxMM2Ro_MPog==..xml
# ./annotations/_NkLYIfVXINkxMM2Ro_MPog==..xml
# ./annotations/_NkLYIfVXINkxMM2Ro_MPog==..xml
# ./annotations/_NkLYIfVXINkxMM2Ro_MPog==..xml
# Formating instance xml file _NkLYIfVXINkxMM2Ro_MPog==..jpg done!
# ./annotations/_oesggSj7lcqanqmLokLE9g==..xml
# ./annotations/_oesggSj7lcqanqmLokLE9g==..xml
# ./annotations/_oesggSj7lcqanqmLokLE9g==..xml
# ./annotations/_oesggSj7lcqanqmLokLE9g==..xml
# ./annotations/_oesggSj7lcqanqmLokLE9g==..xml
# ./annotations/_oesggSj7lcqanqmLokLE9g==..xml
# Formating instance xml file _oesggSj7lcqanqmLokLE9g==..jpg done!
# ./annotations/_Q3b+XGy1vbLjCBjWIm8Evg==..xml
# ./annotations/_Q3b+XGy1vbLjCBjWIm8Evg==..xml
# ./annotations/_Q3b+XGy1vbLjCBjWIm8Evg==..xml
# ./annotations/_Q3b+XGy1vbLjCBjWIm8Evg==..xml
# ./annotations/_Q3b+XGy1vbLjCBjWIm8Evg==..xml
# ./annotations/_Q3b+XGy1vbLjCBjWIm8Evg==..xml
# Formating instance xml file _Q3b+XGy1vbLjCBjWIm8Evg==..jpg done!
# ./annotations/_rM9f9VkufiMz58m4ApvE0Q==..xml
# ./annotations/_rM9f9VkufiMz58m4ApvE0Q==..xml
# ./annotations/_rM9f9VkufiMz58m4ApvE0Q==..xml
# ./annotations/_rM9f9VkufiMz58m4ApvE0Q==..xml
# ./annotations/_rM9f9VkufiMz58m4ApvE0Q==..xml
# Formating instance xml file _rM9f9VkufiMz58m4ApvE0Q==..jpg done!
# ./annotations/_TdfaEXh3lyyh_LLFFxZlCA==..xml
# ./annotations/_TdfaEXh3lyyh_LLFFxZlCA==..xml
# ./annotations/_TdfaEXh3lyyh_LLFFxZlCA==..xml
# ./annotations/_TdfaEXh3lyyh_LLFFxZlCA==..xml
# ./annotations/_TdfaEXh3lyyh_LLFFxZlCA==..xml
# ./annotations/_TdfaEXh3lyyh_LLFFxZlCA==..xml
# Formating instance xml file _TdfaEXh3lyyh_LLFFxZlCA==..jpg done!
# ./annotations/_uqBk_kjEh2TTwz7GyfeCnQ==..xml
# ./annotations/_uqBk_kjEh2TTwz7GyfeCnQ==..xml
# ./annotations/_uqBk_kjEh2TTwz7GyfeCnQ==..xml
# ./annotations/_uqBk_kjEh2TTwz7GyfeCnQ==..xml
# ./annotations/_uqBk_kjEh2TTwz7GyfeCnQ==..xml
# Formating instance xml file _uqBk_kjEh2TTwz7GyfeCnQ==..jpg done!
# ./annotations/_w12nKa44Kw1v0lXA1Yfwmg==..xml
# ./annotations/_w12nKa44Kw1v0lXA1Yfwmg==..xml
# ./annotations/_w12nKa44Kw1v0lXA1Yfwmg==..xml
# ./annotations/_w12nKa44Kw1v0lXA1Yfwmg==..xml
# ./annotations/_w12nKa44Kw1v0lXA1Yfwmg==..xml
# Formating instance xml file _w12nKa44Kw1v0lXA1Yfwmg==..jpg done!
# ./annotations/_XacWcOEKnWH5UpDoYHBpCQ==..xml
# ./annotations/_XacWcOEKnWH5UpDoYHBpCQ==..xml
# ./annotations/_XacWcOEKnWH5UpDoYHBpCQ==..xml
# ./annotations/_XacWcOEKnWH5UpDoYHBpCQ==..xml
# ./annotations/_XacWcOEKnWH5UpDoYHBpCQ==..xml
# Formating instance xml file _XacWcOEKnWH5UpDoYHBpCQ==..jpg done!
# ./annotations/_yIUomnmqPgOcX5ceQwSqlA==..xml
# ./annotations/_yIUomnmqPgOcX5ceQwSqlA==..xml
# ./annotations/_yIUomnmqPgOcX5ceQwSqlA==..xml
# ./annotations/_yIUomnmqPgOcX5ceQwSqlA==..xml
# ./annotations/_yIUomnmqPgOcX5ceQwSqlA==..xml
# Formating instance xml file _yIUomnmqPgOcX5ceQwSqlA==..jpg done!
# ./annotations/_ZyQXvk67fhT_KHFeLALhtg==..xml
# ./annotations/_ZyQXvk67fhT_KHFeLALhtg==..xml
# ./annotations/_ZyQXvk67fhT_KHFeLALhtg==..xml
# ./annotations/_ZyQXvk67fhT_KHFeLALhtg==..xml
# ./annotations/_ZyQXvk67fhT_KHFeLALhtg==..xml
# ./annotations/_ZyQXvk67fhT_KHFeLALhtg==..xml
# Formating instance xml file _ZyQXvk67fhT_KHFeLALhtg==..jpg done!
# ./annotations/_EHzujGmQvTpfONaBmArVxw==..xml
# ./annotations/_EHzujGmQvTpfONaBmArVxw==..xml
# ./annotations/_EHzujGmQvTpfONaBmArVxw==..xml
# Formating instance xml file _EHzujGmQvTpfONaBmArVxw==..jpg done!
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# ./annotations/_vTNBmImNX2R5aHkBF5RTnw==..xml
# Formating instance xml file _vTNBmImNX2R5aHkBF5RTnw==..jpg done!
# ./annotations/48311-44818_wsVnNwPU+06KdldDjM74VA==..xml
# ./annotations/48311-44818_wsVnNwPU+06KdldDjM74VA==..xml
# ./annotations/48311-44818_wsVnNwPU+06KdldDjM74VA==..xml
# ./annotations/48311-44818_wsVnNwPU+06KdldDjM74VA==..xml
# ./annotations/48311-44818_wsVnNwPU+06KdldDjM74VA==..xml
# ./annotations/48311-44818_wsVnNwPU+06KdldDjM74VA==..xml
# ./annotations/48311-44818_wsVnNwPU+06KdldDjM74VA==..xml
# ./annotations/48311-44818_wsVnNwPU+06KdldDjM74VA==..xml
# Formating instance xml file 48311-44818_wsVnNwPU+06KdldDjM74VA==..jpg done!
# ./annotations/_+Z9sqsyv9wF9pANx1Dmoyg==..xml
# ./annotations/_+Z9sqsyv9wF9pANx1Dmoyg==..xml
# ./annotations/_+Z9sqsyv9wF9pANx1Dmoyg==..xml
# ./annotations/_+Z9sqsyv9wF9pANx1Dmoyg==..xml
# ./annotations/_+Z9sqsyv9wF9pANx1Dmoyg==..xml
# Formating instance xml file _+Z9sqsyv9wF9pANx1Dmoyg==..jpg done!
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# ./annotations/_9qQfbzQT8ej5Outh5ktQeA==..xml
# Formating instance xml file _9qQfbzQT8ej5Outh5ktQeA==..jpg done!
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# ./annotations/_f8e3HtaoiKwJ0Jfe2FiO_Q==..xml
# Formating instance xml file _f8e3HtaoiKwJ0Jfe2FiO_Q==..jpg done!
# ./annotations/_gtqyXt7d6LC5zyQkHmRDww==..xml
# ./annotations/_gtqyXt7d6LC5zyQkHmRDww==..xml
# ./annotations/_gtqyXt7d6LC5zyQkHmRDww==..xml
# ./annotations/_gtqyXt7d6LC5zyQkHmRDww==..xml
# Formating instance xml file _gtqyXt7d6LC5zyQkHmRDww==..jpg done!
# ./annotations/_KkUAsA4uDWdavMRMoWHMUg==..xml
# ./annotations/_KkUAsA4uDWdavMRMoWHMUg==..xml
# ./annotations/_KkUAsA4uDWdavMRMoWHMUg==..xml
# ./annotations/_KkUAsA4uDWdavMRMoWHMUg==..xml
# ./annotations/_KkUAsA4uDWdavMRMoWHMUg==..xml
# Formating instance xml file _KkUAsA4uDWdavMRMoWHMUg==..jpg done!
# ./annotations/_pogbbJj9_PmGX64DrUj3pQ==..xml
# ./annotations/_pogbbJj9_PmGX64DrUj3pQ==..xml
# ./annotations/_pogbbJj9_PmGX64DrUj3pQ==..xml
# ./annotations/_pogbbJj9_PmGX64DrUj3pQ==..xml
# ./annotations/_pogbbJj9_PmGX64DrUj3pQ==..xml
# Formating instance xml file _pogbbJj9_PmGX64DrUj3pQ==..jpg done!
# ./annotations/_TPjxr_2fyx5sbJN74eRuyQ==..xml
# ./annotations/_TPjxr_2fyx5sbJN74eRuyQ==..xml
# ./annotations/_TPjxr_2fyx5sbJN74eRuyQ==..xml
# ./annotations/_TPjxr_2fyx5sbJN74eRuyQ==..xml
# ./annotations/_TPjxr_2fyx5sbJN74eRuyQ==..xml
# ./annotations/_TPjxr_2fyx5sbJN74eRuyQ==..xml
# Formating instance xml file _TPjxr_2fyx5sbJN74eRuyQ==..jpg done!
# ./annotations/_ydR_ce4Ax4qROLKESb4XqQ==..xml
# ./annotations/_ydR_ce4Ax4qROLKESb4XqQ==..xml
# ./annotations/_ydR_ce4Ax4qROLKESb4XqQ==..xml
# ./annotations/_ydR_ce4Ax4qROLKESb4XqQ==..xml
# ./annotations/_ydR_ce4Ax4qROLKESb4XqQ==..xml
# ./annotations/_ydR_ce4Ax4qROLKESb4XqQ==..xml
# Formating instance xml file _ydR_ce4Ax4qROLKESb4XqQ==..jpg done!
# ./annotations/_Ybp7N0WP1wiC6i8vK5fjtw==..xml
# Formating instance xml file _Ybp7N0WP1wiC6i8vK5fjtw==..jpg done!
# ./annotations/_BLuVl81qe+7OpjGek+wsvQ==..xml
# ./annotations/_BLuVl81qe+7OpjGek+wsvQ==..xml
# ./annotations/_BLuVl81qe+7OpjGek+wsvQ==..xml
# ./annotations/_BLuVl81qe+7OpjGek+wsvQ==..xml
# ./annotations/_BLuVl81qe+7OpjGek+wsvQ==..xml
# ./annotations/_BLuVl81qe+7OpjGek+wsvQ==..xml
# ./annotations/_BLuVl81qe+7OpjGek+wsvQ==..xml
# ./annotations/_BLuVl81qe+7OpjGek+wsvQ==..xml
# ./annotations/_BLuVl81qe+7OpjGek+wsvQ==..xml
# Formating instance xml file _BLuVl81qe+7OpjGek+wsvQ==..jpg done!
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# ./annotations/_P6bFJ9QknpbwsMCuRSMGzA==..xml
# Formating instance xml file _P6bFJ9QknpbwsMCuRSMGzA==..jpg done!

# %% [markdown]
# ## Prepare data
# ### Resize images to less than 6MB

# %%
from PIL import Image
import glob
import ntpath
import shutil
import json
import pdb
from pathlib import Path

# %%
resizeFactors = {}

source = './images/*'
dest = './imagesResized/'
newSize = 6000000 # bytes equal to 6MB

for filepath in glob.iglob(source):
    fileName = ntpath.basename(filepath)
    fileSize = os.stat(filepath).st_size

    if(fileSize > newSize):
        #resize if larger than newSize
        image = Image.open(filepath)
        resizeFactor = 1 - (fileSize - newSize)/fileSize
        resizeFactors[fileName] = resizeFactor
        newX = round(image.size[0] * resizeFactor)
        newY = round(image.size[1] * resizeFactor)

        image = image.resize((newX,newY), Image.ANTIALIAS)
        image.save(dest + fileName, optimize=True, quality=95)
        
        saveSize = os.stat(dest + fileName).st_size
        print(fileName + ' resized. New size:', str(saveSize/1000000), 'Factor:', str(resizeFactor))
    else:
        #copy without resizing
        shutil.copy(filepath, dest)
        print(fileName + ' copied without resizing. Size:', str(fileSize/1000000))

#write resize factors to json file
json = json.dumps(resizeFactors)
f = open("./resizeFactors.json","w")
f.write(json)
f.close()
# Out:
# 43473-39705_r8oNR+IVSJ+IsZLyGdj1bw==..jpg copied without resizing. Size: 4.83416
# _TdfaEXh3lyyh_LLFFxZlCA==..jpg resized. New size: 3.52409 Factor: 0.6995078612442216
# _ToOjW7j5E9ZYbtIfdfFVww==..jpg resized. New size: 3.773155 Factor: 0.7105281201569367
# _TPjxr_2fyx5sbJN74eRuyQ==..jpg resized. New size: 3.477287 Factor: 0.7021393718567561
# _u38mqKgH3oqFeH0aqNN01A==..jpg resized. New size: 1.910988 Factor: 0.34951227600704826
# _uciWq0uDZ58278SsfL8P7w==..jpg resized. New size: 2.599822 Factor: 0.45542086314853547
# _uqBk_kjEh2TTwz7GyfeCnQ==..jpg resized. New size: 3.180819 Factor: 0.6297804270541076
# _vcDZ8PNy0+PXDTH0BOnHeQ==..jpg copied without resizing. Size: 4.058084
# _vTNBmImNX2R5aHkBF5RTnw==..jpg resized. New size: 2.554085 Factor: 0.47079453561337037
# _w05T7MCiPFNBTqdZ7J4Ebw==..jpg resized. New size: 3.005715 Factor: 0.5217958019962342
# _w12nKa44Kw1v0lXA1Yfwmg==..jpg resized. New size: 3.400046 Factor: 0.6829324481921754
# _XacWcOEKnWH5UpDoYHBpCQ==..jpg resized. New size: 3.60079 Factor: 0.7342305630814188
# _Ybp7N0WP1wiC6i8vK5fjtw==..jpg resized. New size: 2.734876 Factor: 0.4742527397185563
# _yCEU4OXNxeK8dFvNZKynFw==..jpg resized. New size: 3.642058 Factor: 0.6759584668586014
# _ydR_ce4Ax4qROLKESb4XqQ==..jpg resized. New size: 3.00437 Factor: 0.5968645511399516
# _yIUomnmqPgOcX5ceQwSqlA==..jpg resized. New size: 4.036114 Factor: 0.842426153625395
# _yMVtyS4P2CCdH7DZZKEG1w==..jpg resized. New size: 3.679176 Factor: 0.7526822773807309
# _zL7kG1WfdnGt484mnnkNMg==..jpg resized. New size: 3.802263 Factor: 0.7168587250667575
# _ZyQXvk67fhT_KHFeLALhtg==..jpg resized. New size: 4.205146 Factor: 0.88803164234348
# __XSa9hJq_GZEu_o21p_oIg==..jpg resized. New size: 3.81966 Factor: 0.7827906093829197

# %% [markdown]
# ## Create a Custom Vision service project

# %%
# Get workspace environment configs
import os
import azureml.core
from azureml.core.compute import ComputeTarget, DataFactoryCompute
from azureml.exceptions import ComputeTargetException
from azureml.core import Workspace, Experiment
from azureml.pipeline.core import Pipeline
from azureml.core.datastore import Datastore
from azureml.data.data_reference import DataReference
from azureml.pipeline.steps import DataTransferStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# SDK version: 1.0.85
# exelonclearsight
# exelonclearsight
# northcentralus
# c9cf37d1-b965-431c-8eab-91b60c77b93a

# %%
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry, Region

ENDPOINT = "https://mscvpoc-cogservices.cognitiveservices.azure.com/"

# Replace with a valid key
training_key = "5d9d4101ef7d417b94441bd8d2d07b08"
prediction_key = "221b7c70884e4b268dd43ce40842fab0"
prediction_resource_id = "/subscriptions/834ecbdb-c8e6-49c7-81da-2ceb47cb97a6/resourceGroups/MS-CV-POC-RG/providers/Microsoft.CognitiveServices/accounts/mscvpoccogservices-Prediction"#"/subscriptions/c9cf37d1-b965-431c-8eab-91b60c77b93a/resourceGroups/exelonClearsight/providers/Microsoft.CognitiveServices/accounts/exelonClearsight-Prediction"

trainer = CustomVisionTrainingClient(training_key, endpoint=ENDPOINT)

# Find the object detection domain
obj_detection_domain = next(domain for domain in trainer.get_domains() if domain.type == "ObjectDetection" and domain.name == "General")

# %%
# Create a new project
print ("Creating project...")
project = trainer.create_project("Custom Vision Deep Dive", domain_id=obj_detection_domain.id)

if(project is not None):
    print('Project created successfully')
else:
    print('Project creation failed')
# Out:
# Creating project...
# Project created successfully

# %% [markdown]
# ## Create a Custom Vision service project
# ### Apply resizing factor and normalize tag coordinates

# %%
import xml.etree.ElementTree as ET
from pathlib import Path
from PIL import Image
import ntpath

# Import resize factors from json file
import json
f = open('resizeFactors.json')
resizeDict = json.load(f)
f.close()

# Create dictionary of tag names and tag object
tagDict = {}

# Helper function to return dictionary of all tag names and corresponding normalized coordinates
def getTagsNorm(xml_file: str, imagePath):
    img = Image.open(imagePath)
    width, height = img.size
    
    key = ntpath.basename(imagePath)
    resizeList = list(resizeDict.keys())

    if key in resizeList:
        resizeFactor = resizeDict[key]
    else:
        resizeFactor = 1

    tree = ET.parse(xml_file)
    root = tree.getroot()

    list_with_all_boxes = []
    
    filename = root.find('filename').text
    
    #Create Dict from tagDict
    Dict = {key: [] for key in tagDict}
    
    for boxes in root.iter('object'):

        tag = boxes.find('name').text
        ymin, xmin, ymax, xmax = None, None, None, None

        for box in boxes.findall("bndbox"):
            xmin = int(box.find("xmin").text) * resizeFactor
            ymin = int(box.find("ymin").text) * resizeFactor
            xmax = int(box.find("xmax").text) * resizeFactor
            ymax = int(box.find("ymax").text) * resizeFactor
            
            # Normalize coordinates are given in the order: left, top, width, height.
            xNorm = xmin / width
            YNorm = ymin / height
            w = (xmax - xmin)/width
            h = (ymax - ymin)/height

        list_with_single_boxes = [xNorm, YNorm, w, h]
        list_with_all_boxes.append(list_with_single_boxes)
        
        if tag in tagDict:
            Dict[tag].append(list_with_single_boxes)
        else:
            print("Create new tag:", tag)
            tagDict[tag] = trainer.create_tag(project.id, tag)
            Dict[tag] = [list_with_single_boxes]
            
    return filename, Dict

# %% [markdown]
# ## Create a Custom Vision service project
# ### Upload images and tag to project

# %%
# Upload and tag images
from pathlib import Path
import glob
import ntpath

xmlPath = "./annotations/"
imagePath = "./imagesResized/"

for filepath in glob.iglob(imagePath +'*'):
    fileName = Path(filepath).name
    fileStem = Path(filepath).stem # removes file extension
    xmlsFilePath = xmlPath + fileStem + '.xml'
    
    name, tags = getTagsNorm(xmlsFilePath, filepath)
    regions = []
    
    for t in tags:
        tagObj = tagDict[t]
        
        for box in tags[t]:
            x,y,w,h = box
            regions.append( Region(tag_id=tagObj.id, left=x,top=y,width=w,height=h) )
            
    with open(filepath, mode="rb") as image_contents:
        entry = ImageFileCreateEntry(name=fileName, contents=image_contents.read(), regions=regions)

    upload_result = trainer.create_images_from_files(project.id, images=[entry])
    if not upload_result.is_batch_successful:
        print("Image batch upload failed.")
        for image in upload_result.images:
            print("Image status: ", image.status)
        exit(-1)
    else:
        print("Upload of " + fileName + " successful!")
# Out:
# Create new tag: Crossarm
# Create new tag: Pole
# Create new tag: Insulator
# Upload of 43473-39705_r8oNR+IVSJ+IsZLyGdj1bw==..jpg successful!
# Create new tag: -1
# Create new tag: Pole Top
# Upload of 43489-39586_sDQABWrQ8qV_rm3I+dXXYA==..jpg successful!
# Upload of 43592-39684_kPzk8zqAB_C_KTmnUx7z3Q==..jpg successful!
# Upload of 43725-39733_yGt4MZnXZqTu5S0YJNdCoQ==..jpg successful!
# Upload of 43795-39759_hhAvT6bZSUqiX1Uvnm_htw==..jpg successful!
# Upload of 43968-39826_i+19otkVp_NCWi94YYimFw==..jpg successful!
# Upload of 44183-39843_xkWlCFjb85re0JdZbTgAOQ==..jpg successful!
# Upload of 45577-39954_EUPG_1RCGsN_30l5Qimp0g==..jpg successful!
# Upload of 45598-40066_8Y3lqDsgdAaSoUXvDjxwIA==..jpg successful!
# Upload of 47956-45186_g515Tcx6AHWlXCskf8gCNA==..jpg successful!
# Upload of 48026-45295_1VCnpc2LJhqhznRoPhzktg==..jpg successful!
# Upload of 48027-45005_XJ+yidGceiNZ1B0PfaRjCg==..jpg successful!
# Upload of 48033-45002_pi56n0Q4+uyKqrwY+yLuqg==..jpg successful!
# Create new tag: Switch
# Upload of 48058-44984_SC4V7cYLhqLe7m7o5e_Q2g==..jpg successful!
# Create new tag: Transformer
# Upload of 48149-45368_c5uvy3EzUX5CTZGJeZb2Eg==..jpg successful!
# Upload of 48254-44861_YCfn84E91kzEu6xdbISP3A==..jpg successful!
# Upload of 48260-44857_VlUufXXqjUG2jwJlMpK1sQ==..jpg successful!
# Upload of 48264-45436_HXR_D9ZR6d20tVst8AxAJA==..jpg successful!
# Upload of 48311-44818_wsVnNwPU+06KdldDjM74VA==..jpg successful!
# Upload of 48403-44757_RgXpxUsjClQQTX0jYGcvzg==..jpg successful!
# Upload of 48447-44748_OkxAwY73K6UgXm7xbRlG2A==..jpg successful!
# Upload of 48449-44716_T5qmwRUNIx_cvvSwjSBO_g==..jpg successful!
# Create new tag: Cutout Fuse Barrel
# Upload of 48517-45586_BYZvoL_B_X9H8Tjet5_26g==..jpg successful!
# Upload of 48540-44641_jJgWMZLcj3Nr8CDj+Tf68w==..jpg successful!
# Upload of 48602-45701_iZS5mWpIePH_kucVcIATYw==..jpg successful!
# Upload of 48616-45641_ViGQs96JhXKOkKP4wWac8w==..jpg successful!
# Upload of 48798-44655_WkJ6RBgq04n6T7qafQ1yzA==..jpg successful!
# Upload of _+Z9sqsyv9wF9pANx1Dmoyg==..jpg successful!
# Upload of _1im_mPd94ZKhS9XpmvE4rQ==..jpg successful!
# Upload of _M4Zpolym1GroX+M6aYx6fg==..jpg successful!
# Upload of _MNLlJAigCS8D285CSP0jsg==..jpg successful!
# Upload of _NkLYIfVXINkxMM2Ro_MPog==..jpg successful!
# Upload of _oesggSj7lcqanqmLokLE9g==..jpg successful!
# Upload of _Ofv4uL7f3LqG4hhLUfpoqQ==..jpg successful!
# Upload of _p+bWcTEBcnb5FMQkLT819w==..jpg successful!
# Upload of _P6bFJ9QknpbwsMCuRSMGzA==..jpg successful!
# Upload of _pogbbJj9_PmGX64DrUj3pQ==..jpg successful!
# Upload of _PRCuKUcqrNJZ1cnty50AYA==..jpg successful!
# Upload of _Q+EXRc+IeEa0ZIa667cspA==..jpg successful!
# Upload of _Q3b+XGy1vbLjCBjWIm8Evg==..jpg successful!
# Upload of _qdSoSQz44kg5rxUCgY86jw==..jpg successful!
# Upload of _rM9f9VkufiMz58m4ApvE0Q==..jpg successful!
# Upload of _t3_yc0oeHJDH3fIdIiSXHA==..jpg successful!
# Upload of _TdfaEXh3lyyh_LLFFxZlCA==..jpg successful!
# Upload of _ToOjW7j5E9ZYbtIfdfFVww==..jpg successful!
# Upload of _TPjxr_2fyx5sbJN74eRuyQ==..jpg successful!
# Upload of _u38mqKgH3oqFeH0aqNN01A==..jpg successful!
# Upload of _uciWq0uDZ58278SsfL8P7w==..jpg successful!
# Upload of _uqBk_kjEh2TTwz7GyfeCnQ==..jpg successful!
# Upload of _vcDZ8PNy0+PXDTH0BOnHeQ==..jpg successful!
# Upload of _vTNBmImNX2R5aHkBF5RTnw==..jpg successful!
# Upload of _w05T7MCiPFNBTqdZ7J4Ebw==..jpg successful!
# Upload of _w12nKa44Kw1v0lXA1Yfwmg==..jpg successful!
# Upload of _XacWcOEKnWH5UpDoYHBpCQ==..jpg successful!
# Upload of _Ybp7N0WP1wiC6i8vK5fjtw==..jpg successful!
# Upload of _yCEU4OXNxeK8dFvNZKynFw==..jpg successful!
# Upload of _ydR_ce4Ax4qROLKESb4XqQ==..jpg successful!
# Upload of _yIUomnmqPgOcX5ceQwSqlA==..jpg successful!
# Upload of _yMVtyS4P2CCdH7DZZKEG1w==..jpg successful!
# Upload of _zL7kG1WfdnGt484mnnkNMg==..jpg successful!
# Upload of _ZyQXvk67fhT_KHFeLALhtg==..jpg successful!
# Upload of __XSa9hJq_GZEu_o21p_oIg==..jpg successful!

# %% [markdown]
# ## Create a Custom Vision service project
# ### Train the project - Select the tags you want to train on

# %% [markdown]
# ### Select the tags you want to train on
# `train_project(project_id,
# training_type=None,
# reserved_budget_in_hours=0,
# force_train=False,
# notification_email_address=None,
# selected_tags=None,
# custom_headers=None,
# raw=False, **operation_config)`

# %%
SELECTED_TAGS = ['Crossarm', 'Insulator', 'Pole', 'Transformer']
import time
print ("Training...")
iteration = trainer.train_project(project.id, selected_tags=SELECTED_TAGS)
while (iteration.status == "Training"):
    iteration = trainer.get_iteration(project.id, iteration.id)
    print ("Training status: " + iteration.status)
    time.sleep(30)
# Out:
# Training...
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Completed
